# %%
from LeidenViewer import *

# %% [markdown]
# # Example data plotting from single log file

# %%
Minion = LeidenFridge('./data/LogAVS___2021-03-05-09-58-29_4.dat')
Minion.plot(channels=[1,2,3,4,5])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Example interactive plotting

# %%
# %matplotlib widget
Minion = LeidenFridge('./data/LogAVS___2021-03-05-09-58-29_4.dat')
Minion.plot_interactive()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(Checkbox(value=False, description='T0'), Checkbox(value=False, description='T1'), Checkb…
# (<Figure size 1000x600 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# # Example data plotting from multiple log files

# %%
Minion = LeidenFridge('./data')
Minion.plot(channels=[1,2,3,4,5])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:>

# %%
Minion.T.head()
# Out:
# Date1                           T0           T1         T2          T3  \
# Date(String)               C_still           3K      Still MC - TT1810
#                     No Calibration RuO2-10K-NEW   RuO2 10k     TT-1810
# 2021-02-26 09:58:13   1.867805e-10    38333.248  86798.358   20981.207
# 2021-02-26 09:58:51   1.867756e-10    38338.236  86788.166   20949.286
# 2021-02-26 09:59:31   1.867701e-10    38331.088  86823.765   20902.505
# 2021-02-26 10:00:09   1.867689e-10    38326.003  86838.203   21100.292
# 2021-02-26 10:00:47   1.867673e-10    38337.031  86832.848   21011.541
#
# Date1                         T4         T5                  T6  \
# Date(String)         MC - Cernox      50 mK Unnamed: 18_level_1
#                     CernoxA - mk   RuO2 1k5      No Calibration
# 2021-02-26 09:58:13   290820.527  12370.202                 0.0
# 2021-02-26 09:58:51   290819.006  12369.662                 0.0
# 2021-02-26 09:59:31   290818.020  12369.712                 0.0
# 2021-02-26 10:00:09   290819.803  12369.759                 0.0
# 2021-02-26 10:00:47   290838.833  12369.209                 0.0
#
# Date1                                T7                  T8     T9  \
# Date(String)        Unnamed: 19_level_1 Unnamed: 20_level_1    50K
#                          No Calibration      No Calibration PT1000
# 2021-02-26 09:58:13                 0.0                 0.0    NaN
# 2021-02-26 09:58:51                 0.0                 0.0    NaN
# 2021-02-26 09:59:31                 0.0                 0.0    NaN
# 2021-02-26 10:00:09                 0.0                 0.0    NaN
# 2021-02-26 10:00:47                 0.0                 0.0    NaN
#
# Date1
# Date(String)        Unnamed: 21_level_1
#                          No Calibration PT1000
# 2021-02-26 09:58:13                 0.0    NaN
# 2021-02-26 09:58:51                 0.0    NaN
# 2021-02-26 09:59:31                 0.0    NaN
# 2021-02-26 10:00:09                 0.0    NaN
# 2021-02-26 10:00:47                 0.0    NaN
