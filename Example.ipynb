# %%
from LeidenViewer import *

# %% [markdown]
# # Example data plotting from single log file

# %%
Minion = LeidenFridge('./data/LogAVS___2021-03-05-09-58-29_4.dat')
Minion.plot(channels=[1,2,3,4,5])
# Out:
# <AxesSubplot:>

# %%
Minion.T.head()
# Out:
# Date1                           T0           T1         T2          T3  \
# Date(String)               C_still           3K      Still MC - TT1810
#                     No Calibration RuO2-10K-NEW   RuO2 10k     TT-1810
# 2021-03-05 09:58:35   1.756880e-10    36761.349  83095.471   20920.417
# 2021-03-05 09:59:13   1.756752e-10    36770.789  83094.476   20920.417
# 2021-03-05 09:59:51   1.756836e-10    36766.847  83081.519   20920.417
# 2021-03-05 10:00:29   1.756961e-10    36763.475  83075.643   20920.417
# 2021-03-05 10:01:07   1.756993e-10    36758.353  83107.261   20920.417
#
# Date1                         T4         T5                  T6  \
# Date(String)         MC - Cernox      50 mK Unnamed: 18_level_1
#                     CernoxA - mk   RuO2 1k5      No Calibration
# 2021-03-05 09:58:35   136307.308  12986.475                 0.0
# 2021-03-05 09:59:13   136272.523  12987.057                 0.0
# 2021-03-05 09:59:51   136239.000  12987.438                 0.0
# ...

# %% [markdown]
# # Example data plotting from multiple log files

# %%
Minion = LeidenFridge('./data')
Minion.plot(channels=[1,2,3,4,5])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Example interactive plotting

# %%
# %matplotlib widget
Minion = LeidenFridge('./data/LogAVS___2021-03-05-09-58-29_4.dat')
Minion.plot_interactive()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(Checkbox(value=False, description='T0'), Checkbox(value=False, description='T1'), Checkb…
# (<Figure size 1000x600 with 1 Axes>, <AxesSubplot:>)
